# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data=pd.read_csv('/content/df_arabica_clean.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  ID Country of Origin                 Farm Name  \
# 0           0   0          Colombia          Finca El Paraiso
# 1           1   1            Taiwan  Royal Bean Geisha Estate
# 2           2   2              Laos        OKLAO coffee farms
# 3           3   3        Costa Rica                 La Cumbre
# 4           4   4          Colombia           Finca Santuario
#
#                                 Lot Number                           Mill  \
# 0                               CQU2022015               Finca El Paraiso
# 1  The 2022 Pacific Rim Coffee Summit,T037       Royal Bean Geisha Estate
# 2  The 2022 Pacific Rim Coffee Summit,LA01  oklao coffee processing plant
# 3                               CQU2022017        La Montana Tarrazu MIll
# 4                               CQU2023002                Finca Santuario
#
#   ICO Number                   Company   Altitude                Region  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             207 non-null    int64
#  1   ID                     207 non-null    int64
#  2   Country of Origin      207 non-null    object
#  3   Farm Name              205 non-null    object
#  4   Lot Number             206 non-null    object
#  5   Mill                   204 non-null    object
#  6   ICO Number             75 non-null     object
#  7   Company                207 non-null    object
#  8   Altitude               206 non-null    object
#  9   Region                 205 non-null    object
#  10  Producer               206 non-null    object
#  11  Number of Bags         207 non-null    int64
#  12  Bag Weight             207 non-null    object
#  13  In-Country Partner     207 non-null    object
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0          ID  Number of Bags       Aroma      Flavor  \
# count  207.000000  207.000000      207.000000  207.000000  207.000000
# mean   103.000000  103.000000      155.449275    7.721063    7.744734
# std     59.899917   59.899917      244.484868    0.287626    0.279613
# min      0.000000    0.000000        1.000000    6.500000    6.750000
# 25%     51.500000   51.500000        1.000000    7.580000    7.580000
# 50%    103.000000  103.000000       14.000000    7.670000    7.750000
# 75%    154.500000  154.500000      275.000000    7.920000    7.920000
# max    206.000000  206.000000     2240.000000    8.580000    8.500000
#
#        Aftertaste    Acidity        Body     Balance  Uniformity  Clean Cup  \
# count  207.000000  207.00000  207.000000  207.000000  207.000000      207.0
# mean     7.599758    7.69029    7.640918    7.644058    9.990338       10.0
# std      0.275911    0.25951    0.233499    0.256299    0.103306        0.0
# ...

# %% [markdown]
# Data Cleaning

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                 0
# ID                         0
# Country of Origin          0
# Farm Name                  2
# Lot Number                 1
# Mill                       3
# ICO Number               132
# Company                    0
# Altitude                   1
# Region                     2
# Producer                   1
# Number of Bags             0
# Bag Weight                 0
# In-Country Partner         0
# Harvest Year               0
# Grading Date               0
# Owner                      0
# Variety                    6
# Status                     0
# Processing Method          5
# Aroma                      0
# Flavor                     0
# Aftertaste                 0
# Acidity                    0
# Body                       0
# Balance                    0
# Uniformity                 0
# Clean Cup                  0
# Sweetness                  0
# Overall                    0
# Defects                    0
# Total Cup Points           0
# ...

# %%
data.drop(columns=['ICO Number'], inplace=True)

# %%
data.isnull().sum()/len(data)
# Out:
# Unnamed: 0               0.000000
# ID                       0.000000
# Country of Origin        0.000000
# Farm Name                0.009662
# Lot Number               0.004831
# Mill                     0.014493
# Company                  0.000000
# Altitude                 0.004831
# Region                   0.009662
# Producer                 0.004831
# Number of Bags           0.000000
# Bag Weight               0.000000
# In-Country Partner       0.000000
# Harvest Year             0.000000
# Grading Date             0.000000
# Owner                    0.000000
# Variety                  0.028986
# Status                   0.000000
# Processing Method        0.024155
# Aroma                    0.000000
# Flavor                   0.000000
# Aftertaste               0.000000
# Acidity                  0.000000
# Body                     0.000000
# Balance                  0.000000
# Uniformity               0.000000
# Clean Cup                0.000000
# ...

# %%
data[['Farm Name','Lot Number','Mill','Altitude','Region','Producer','Variety','Processing Method']].describe(include='all')
# Out:
#                            Farm Name Lot Number      Mill Altitude  Region  \
# count                            205        206       204      206     205
# unique                           172        187       162       97     120
# top     Doi Tung Development Project          1  Dry Mill     1200  Chiayi
# freq                               7         11        11       23      12
#
#                             Producer  Variety Processing Method
# count                            206      201               202
# unique                           172       48                10
# top     Doi Tung Development Project  Caturra      Washed / Wet
# freq                               7       27               124

# %%
# Assuming your DataFrame is named 'data'
columns_to_clean = ['Farm Name', 'Lot Number', 'Mill', 'Altitude', 'Region', 'Producer', 'Variety', 'Processing Method']
data_cleaned = data.dropna(subset=columns_to_clean)

# %%
data.dropna(subset=columns_to_clean, inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# Country of Origin        0
# Farm Name                0
# Lot Number               0
# Mill                     0
# Company                  0
# Altitude                 0
# Region                   0
# Producer                 0
# Number of Bags           0
# Bag Weight               0
# In-Country Partner       0
# Harvest Year             0
# Grading Date             0
# Owner                    0
# Variety                  0
# Status                   0
# Processing Method        0
# Aroma                    0
# Flavor                   0
# Aftertaste               0
# Acidity                  0
# Body                     0
# Balance                  0
# Uniformity               0
# Clean Cup                0
# Sweetness                0
# Overall                  0
# Defects                  0
# Total Cup Points         0
# Moisture Percentage      0
# Category One Defects     0
# Quakers                  0
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0                 int64
# ID                         int64
# Country of Origin         object
# Farm Name                 object
# Lot Number                object
# Mill                      object
# Company                   object
# Altitude                  object
# Region                    object
# Producer                  object
# Number of Bags             int64
# Bag Weight                object
# In-Country Partner        object
# Harvest Year              object
# Grading Date              object
# Owner                     object
# Variety                   object
# Status                    object
# Processing Method         object
# Aroma                    float64
# Flavor                   float64
# Aftertaste               float64
# Acidity                  float64
# Body                     float64
# Balance                  float64
# Uniformity               float64
# Clean Cup                float64
# Sweetness                float64
# ...

# %% [markdown]
# Preprocessing

# %%
for column in data.columns:
    if " " in column:
        new_column=column.replace(" ","_")
        data.rename(columns={column:new_column},inplace=True)
df=data

# %%
# Remove the suffixes from the dates in the "Expiration" column
df['Expiration'] = df['Expiration'].str.replace(r'st|nd|rd|th', '', regex=True)
df['Expiration'] = df['Expiration'].str.replace('Augu', 'August')
# Convert the "Expiration" column to datetime format
df['Expiration'] = pd.to_datetime(df['Expiration'], format='%B %d, %Y')

# Convert the "Expiration" column to datetime format
df['Expiration'] = pd.to_datetime(df['Expiration'], format='%B %d, %Y')

# Extract year, month, and day into separate columns
df['Year'] = df['Expiration'].dt.year
df['Month'] = df['Expiration'].dt.month
df['Day'] = df['Expiration'].dt.day

# Drop the original "Expiration" column
df.drop(columns=['Expiration'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Unnamed:_0  ID Country_of_Origin                 Farm_Name  \
# 0           0   0          Colombia          Finca El Paraiso
# 1           1   1            Taiwan  Royal Bean Geisha Estate
# 2           2   2              Laos        OKLAO coffee farms
# 3           3   3        Costa Rica                 La Cumbre
# 4           4   4          Colombia           Finca Santuario
#
#                                 Lot_Number                           Mill  \
# 0                               CQU2022015               Finca El Paraiso
# 1  The 2022 Pacific Rim Coffee Summit,T037       Royal Bean Geisha Estate
# 2  The 2022 Pacific Rim Coffee Summit,LA01  oklao coffee processing plant
# 3                               CQU2022017        La Montana Tarrazu MIll
# 4                               CQU2023002                Finca Santuario
#
#                     Company   Altitude                Region  \
# 0      Coffee Quality Union  1700-1930        Piendamo,Cauca
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to each categorical column
df["Country_of_Origin"] = label_encoder.fit_transform(df["Country_of_Origin"])
df["Region"] = label_encoder.fit_transform(df["Region"])
df["Bag_Weight"] = label_encoder.fit_transform(df["Bag_Weight"])
df["Variety"] = label_encoder.fit_transform(df["Variety"])
df["Processing_Method"] = label_encoder.fit_transform(df["Processing_Method"])
df["Color"] = label_encoder.fit_transform(df["Color"])

# %%
altitude = df['Altitude'].apply(lambda x: (sum(map(int, x.split('-')))/2 if '-' in x else int(x)) if isinstance(x, str) and x.replace('-', '').isdigit() else np.nan)
altitude.fillna(-1, inplace=True)
df['Altitude'] = altitude.astype(int)

# %%
df['Harvest_Year'] = df['Harvest_Year'].str.extract(r'(\d{4})')
df['Harvest_Year'] = pd.to_numeric(df['Harvest_Year'], errors='coerce')

# %%
df.columns
# Out:
# Index(['Unnamed:_0', 'ID', 'Country_of_Origin', 'Farm_Name', 'Lot_Number',
#        'Mill', 'Company', 'Altitude', 'Region', 'Producer', 'Number_of_Bags',
#        'Bag_Weight', 'In-Country_Partner', 'Harvest_Year', 'Grading_Date',
#        'Owner', 'Variety', 'Status', 'Processing_Method', 'Aroma', 'Flavor',
#        'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity', 'Clean_Cup',
#        'Sweetness', 'Overall', 'Defects', 'Total_Cup_Points',
#        'Moisture_Percentage', 'Category_One_Defects', 'Quakers', 'Color',
#        'Category_Two_Defects', 'Certification_Body', 'Certification_Address',
#        'Certification_Contact', 'Year', 'Month', 'Day'],
#       dtype='object')

# %%
df = data.drop(['ID', 'Country_of_Origin', 'Altitude', 'Region', 'Number_of_Bags',
       'Bag_Weight', 'Harvest_Year', 'Variety', 'Processing_Method','Color','Year', 'Month', 'Day'],axis=1, inplace=True)
df = data.drop(['Unnamed:_0', 'Farm_Name', 'Mill', 'Company',
                  'Producer', 'In-Country_Partner', 'Lot_Number', 'Owner',
                  'Certification_Body', 'Grading_Date', 'Certification_Address',
                  'Certification_Contact','Status'], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance',
#        'Uniformity', 'Clean_Cup', 'Sweetness', 'Overall', 'Defects',
#        'Total_Cup_Points', 'Moisture_Percentage', 'Category_One_Defects',
#        'Quakers', 'Category_Two_Defects'],
#       dtype='object')

# %%
df

# %% [markdown]
# # **Modelling**

# %%
from sklearn.model_selection import train_test_split

# %%
y=data['Total_Cup_Points']
x=data.drop('Total_Cup_Points',axis=1)

# %%
x.head()
# Out:
#    Aroma  Flavor  Aftertaste  Acidity  Body  Balance  Uniformity  Clean_Cup  \
# 0   8.58    8.50        8.42     8.58  8.25     8.42        10.0       10.0
# 1   8.50    8.50        7.92     8.00  7.92     8.25        10.0       10.0
# 2   8.33    8.42        8.08     8.17  7.92     8.17        10.0       10.0
# 3   8.08    8.17        8.17     8.25  8.17     8.08        10.0       10.0
# 4   8.33    8.33        8.08     8.25  7.92     7.92        10.0       10.0
#
#    Sweetness  Overall  Defects  Moisture_Percentage  Category_One_Defects  \
# 0       10.0     8.58      0.0                 11.8                     0
# 1       10.0     8.50      0.0                 10.5                     0
# 2       10.0     8.33      0.0                 10.4                     0
# 3       10.0     8.25      0.0                 11.8                     0
# 4       10.0     8.25      0.0                 11.6                     0
#
#    Quakers  Category_Two_Defects
# ...

# %%
y.head()
# Out:
# 0    89.33
# 1    87.58
# 2    87.42
# 3    87.17
# 4    87.08
# Name: Total_Cup_Points, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# Instantiate StandardScaler
scaler = StandardScaler()

# Fit and transform training data
x_train_scaled = scaler.fit_transform(x_train)

# Transform test data using the same scaler
x_test_scaled = scaler.transform(x_test)

# %%
x.columns
# Out:
# Index(['Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance',
#        'Uniformity', 'Clean_Cup', 'Sweetness', 'Overall', 'Defects',
#        'Moisture_Percentage', 'Category_One_Defects', 'Quakers',
#        'Category_Two_Defects'],
#       dtype='object')

# %%
x.dtypes
# Out:
# Aroma                   float64
# Flavor                  float64
# Aftertaste              float64
# Acidity                 float64
# Body                    float64
# Balance                 float64
# Uniformity              float64
# Clean_Cup               float64
# Sweetness               float64
# Overall                 float64
# Defects                 float64
# Moisture_Percentage     float64
# Category_One_Defects      int64
# Quakers                   int64
# Category_Two_Defects      int64
# dtype: object

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %%
model=Ridge()

# %%
model.fit(x_train_scaled,y_train)
# Out:
# Ridge()

# %%
prediction=model.predict(x_test_scaled)

# %%
from sklearn.metrics import mean_squared_error,r2_score

print(f"the mae:",mean_squared_error(prediction,y_test))
print(f"the r2_score:",r2_score(prediction,y_test))
# Out:
# the mae: 8.399215702764839e-05
# the r2_score: 0.9999660121794126

# %%
plt.scatter(prediction, y_test, color='blue')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Scatter Plot of Predicted vs Actual Values')
plt.show()

# %%
#import pickle

# %%
#pickle.dump(model, open('model4.pkl', 'wb'))  # save

#model = pickle.load(open('model4.pkl','rb'))

# %%
#pickle.dump(scaler, open('scaler3.pkl', 'wb'))
